# %% [markdown]
# # Setup
# Importieren von benötigten Bibiliotheken

# %% [markdown]
# # Analyse von Customer Profile
# Herausfinden der allgemeinen Struktur der Daten und Fehler suchen

# %% [markdown]
# # Analyse von Churn Prediction
# Mit besonderem Fokus auf Null-Werte

# %% [markdown]
# # Analyse von Connection Log
# Überprüfen auf Outlier und fehlerhafte String-Werte

# %% [markdown]
# # Analyse von Agent
# Hinzugefügte Daten der Arbeitskräfte analysieren

# %% [markdown]
# # Analyse von Support Ticket
# Null-Werte identifizieren

# %% [markdown]
# # Analyse von Chat Transkript
# Überprüfen, ob das JSON-Format eingehalten wird und ob fehlerhafte Werte vorliegen
