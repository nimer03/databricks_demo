-- %%
CREATE TABLE IF NOT EXISTS sac.support.chat_bronze (
		session_id STRING,
		customer_id STRING,
		agent_id STRING,
		timestamp_start STRING,
		timestamp_end STRING,
		messages STRING,
		resolution_status STRING,
		log_id STRING,
		chat_reason STRING,
		ingestion_time TIMESTAMP
	)
