-- %%
CREATE TABLE IF NOT EXISTS sac.support.ticket_bronze (
		ticket_id STRING,
		customer_id STRING,
		timestamp_created STRING,
		timestamp_closed STRING,
		subject STRING,
		description STRING,
		category STRING,
		priority STRING,
		channel STRING,
		status STRING,
		solved_in_hours STRING,
		log_id STRING,
		technical_issue_type STRING,
		ingestion_time TIMESTAMP
	);
