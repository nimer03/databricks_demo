-- %%
DELETE FROM 
    sac.customer.customer 
WHERE 
    customer_id IS NOT NULL;

DROP TABLE IF EXISTS sac.support.message;
DROP TABLE IF EXISTS sac.support.chat;
DROP TABLE IF EXISTS sac.customer.churn;
DROP TABLE IF EXISTS sac.network.log;
DROP TABLE IF EXISTS sac.support.ticket;
DROP TABLE IF EXISTS sac.employee.agent;
DROP TABLE IF EXISTS sac.customer.customer;

DROP TABLE IF EXISTS plz_to_state;

DROP TABLE IF EXISTS sac.employee.agent_delete;
DROP TABLE IF EXISTS sac.customer.customer_delete;

DROP TABLE IF EXISTS sac.support.chat_bronze;
DROP TABLE IF EXISTS sac.customer.churn_bronze;
DROP TABLE IF EXISTS sac.network.log_bronze;
DROP TABLE IF EXISTS sac.support.ticket_bronze;
DROP TABLE IF EXISTS sac.employee.agent_bronze;
DROP TABLE IF EXISTS sac.customer.customer_bronze;
 
DROP VIEW IF EXISTS sac.customer.ai_address;
DROP VIEW IF EXISTS sac.support.ai_analyse_message;
DROP VIEW IF EXISTS average_connection_quality;
DROP VIEW IF EXISTS average_customer;
DROP VIEW IF EXISTS chat_issues;
DROP VIEW IF EXISTS churned_customer_details;
DROP VIEW IF EXISTS customer_connection_ticket_count;
DROP VIEW IF EXISTS location_detail;
DROP VIEW IF EXISTS sentiment_for_agent;
