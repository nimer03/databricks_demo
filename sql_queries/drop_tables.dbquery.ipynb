-- %%
DROP TABLE IF EXISTS message;
DROP TABLE IF EXISTS chat;
DROP TABLE IF EXISTS churn;
DROP TABLE IF EXISTS log;
DROP TABLE IF EXISTS ticket;
DROP TABLE IF EXISTS agent;
DROP TABLE IF EXISTS customer;
DROP TABLE IF EXISTS plz_to_state;

DROP TABLE IF EXISTS chat_bronze;
DROP TABLE IF EXISTS churn_bronze;
DROP TABLE IF EXISTS log_bronze;
DROP TABLE IF EXISTS ticket_bronze;
DROP TABLE IF EXISTS agent_bronze;
DROP TABLE IF EXISTS customer_bronze;
