-- %%
-- DB_12: Valide Änderung
SELECT * FROM sac.support.ticket WHERE ticket_id = "TKT_000003";

UPDATE sac.support.ticket_bronze 
SET priority = "high"
WHERE ticket_id = "TKT_000003";

-- DB_13: Nicht valide Änderung
UPDATE sac.support.ticket_bronze
SET timestamp_created = "2026-06-30T04:59:57.000+00:00"
WHERE ticket_id = "TKT_000003";

-- DB_14: Löschen
DESCRIBE HISTORY sac.employee.agent;

-- DB_21: Constraint-Grenze
UPDATE sac.employee.agent
SET monthly_salary_eur = -20
WHERE agent_id = "AGENT_001";

-- DB_22: Fremschlüssel
SELECT * FROM sac.support.ticket WHERE ticket_id = "TKT_000003";

DELETE FROM sac.customer.customer
WHERE customer_id = "CUST_00491"
