-- %%
-- Original fehlende PLZ vs. befüllt
SELECT
	"Summe der KI-Werte" as Bundeland,
	count(*) as Summe
FROM
	sac.customer.customer c
WHERE
	ai_used = TRUE
UNION
SELECT
	zone as Bundeland,
	count(*) as Summe
FROM
	sac.customer.customer c
WHERE
	ai_used = TRUE
GROUP BY
	zone
